# %%
{   
 "metadata":{ 
 "name": "", 
 "signature": "sha256:7ce41b8217731111dc2744862f52dac51796d2a1c7bd2a654d90c488b2f9ba7b"
 }, 
 "nbformat": 3,
 "nbformat_minor": 0,
 "worksheets": [
  {
   "cells": [
    {
     "cell_type": "heading",
     "level": 1,
     "metadata": {},
     "source": [
      "Introduction to iPython, Bridget Connelly #heading for entire program" 
     ] 
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Do some simple math. Add and multiply some numbers. #heading for next section"
     ] 
    },
    {
     "cell_type": "code",
     "collapsed": False, #capitalize every false
     "input": [
      "print(2+56+84+65498+21+22)\n #printing the sum of these numbers", 
      "print(2**8)\n #print 2 raised to 8", 
      "print((1+4)*(9-6)) #print the solution" 
     ],
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "65683\n", #outputs from questions before
        "256\n",
        "15\n"
       ]
      }
     ],
     "prompt_number": 2
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Characters #heading for section 3"
     ] 
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "s = 'spam'\n #the value in s is spam",
      "print(s[0], s[-2])\n #print the first and second to last letters in value", 
      "print(s[1:3], s[1:], s[:-1]) #print the first and third, all but the first, and all but the last letters" 
     ], 
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "s a\n",
        "pa pam spa\n" 
       ]
      }
     ],
     "prompt_number": 7
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Check current working directory # heading"
     ]
    }, 
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "import sys #Load the sys library\n", 
      "import os #Load the os library\n",
      "import re #Load regular expression pattern matching library\n",
      "print(os.getcwd())\n",
      "print(sys.platform)"
     ],
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "/Users/gs13macpro/Box Sync/Gerhard Pilcher/Georgetown Univ/510 Course 2015 Fall/Python\n",
        "darwin\n"
       ]
      }
     ],
     "prompt_number": 10
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Help"
     ]
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "help(os)"
     ],
     "language": "python",
     "metadata": {},
     "outputs": [],
     "prompt_number": 11
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "import urllib.request\n",
      "r = urllib.request.urlopen('https://github.com/Math510/Math510.github.io/raw/master/2015%20FALL%20510%20Course%20Schedule.pdf')\n",
      "myfile = open('/Bridget/Documents/GitHub/Schedule', 'wb')\n #create a folder to put the pdf into", 
      "myfile.write(r.read())\n",
      "myfile.close()"
     ],
     "language": "python",
     "metadata": {},
     "outputs": [],
     "prompt_number": 14
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "r = urllib.request.urlopen('https://github.com/Math510/Math510.github.io/raw/master/2015%20FALL%20510%20Syllabus.pdf')\n",
      "myfile = open('/Bridget/Documents/GitHub/Syllabus.pdf', 'wb')\n #create a folder to put the syllabus into", 
      "myfile.write(r.read())\n",
      "myfile.close()"
     ],
     "language": "python",
     "metadata": {},
     "outputs": [],
     "prompt_number": 16
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Modules #heading for Modules" 
     ]
    },
    {
     "cell_type": "heading",
     "level": 3,
     "metadata": {},
     "source": [
      "Create a variable"
     ]
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "title = 'Something Else'\n #creates variable title, and puts 'Something Else' into it", 
      "print(title) #print variable title's value" 
     ],
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "Something Else\n"
       ]
      }
     ],
     "prompt_number": 2
    },
    {
     "cell_type": "heading",
     "level": 3,
     "metadata": {},
     "source": [
      "Import variables from a module"
     ]
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "import Class_1_Module #uses Class_1_Module name space\n #imports Class_1_Module from the repository Math510", 
      "dir(Class_1_Module)\n",
      "print(Class_1_Module.title)\n",
      "print(Class_1_Module.MyAge)\n",
      "\n",
      "print(title) #prints complete Class_1_Module's from Math510 repository" 
     ],
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "Math 510 Fall 2015\n",
        "54.0\n",
        "Something Else\n"
       ]
      }
     ],
     "prompt_number": 3
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Show the difference in scope between importing a module and importing a specific variable from the module"
     ]
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [
      "#copies into local name space, overwrites same named variable\n",
      "#without warning\n",
      "from Class_1_Module import title \n #imports singular variable from Class_1_Module, instead of complete group", 
      "print(title)"
     ],
     "language": "python",
     "metadata": {},
     "outputs": [
      {
       "output_type": "stream",
       "stream": "stdout",
       "text": [
        "Math 510 Fall 2015\n"
       ]
      }
     ],
     "prompt_number": 4
    },
    {
     "cell_type": "heading",
     "level": 2,
     "metadata": {},
     "source": [
      "Functions"
     ]
    },
    {
     "cell_type": "code",
     "collapsed": False,
     "input": [],
     "language": "python",
     "metadata": {},
     "outputs": []
    }
   ],
   "metadata": {}
  }
 ]
 ""$ ipython nbconvert --to FORMAT notebook.ipynb""
    "#trying to convert the notebook from python code to an html format. Unfortunately it is not working like I want it to. To copy the Python Intro, I simply copied the code from GitHub. I could not understand how to copy it in html format. But now that I have commented and am ready to upload, my document stays in code. I didn't change anything having to do with formatting, so am confused as to why this is happening. My attempts at correcting it aren't getting anywhere either."  
}
# Out:
#   File "<ipython-input-52-d0e4b23dd44d>", line 280
#     ""$ ipython nbconvert --to FORMAT notebook.ipynb""
#      ^
# SyntaxError: invalid syntax
